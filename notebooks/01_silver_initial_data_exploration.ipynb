# %%
# Install required libraries if not installed yet
pip install pandas sqlalchemy pymysql

# %%
import pandas as pd

from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:password@localhost/blinkit_silver"
)

# %%
stores = pd.read_sql("SELECT * FROM stores", engine)

customers = pd.read_sql("SELECT * FROM customers", engine)

products = pd.read_sql("SELECT * FROM products", engine)

riders = pd.read_sql("SELECT * FROM riders", engine)

orders = pd.read_sql("SELECT * FROM orders", engine)

order_items = pd.read_sql("SELECT * FROM order_items", engine)

deliveries = pd.read_sql("SELECT * FROM deliveries", engine)

inventory = pd.read_sql("SELECT * FROM inventory", engine)

# %% [markdown]
# #  Table 01:- Stores

# %%
len(stores)
# Out:
# 15

# %%
stores.head()
# Out:
#   store_id                       store_name    city            area  \
# 0    ST001   Blinkit Raipur - Shankar Nagar  Raipur   Shankar Nagar
# 1    ST002   Blinkit Raipur - Shankar Nagar  Raipur   Shankar Nagar
# 2    ST003        Blinkit Raipur - VIP Road  Raipur        VIP Road
# 3    ST004  Blinkit Bhilai - Vaishali Nagar  BHILAI  Vaishali Nagar
# 4    ST005    Blinkit Bhilai - Smriti Nagar  Bhilai    Smriti Nagar
#
#     latitude  longitude  store_size_sqft opening_date store_status  \
# 0  21.230600  81.644609             1928   2024-12-20       Active
# 1  21.212379  81.603556             1836   2024-12-28       Active
# 2  21.245075  81.629264             1913   2025-01-15       Active
# 3  21.211388  81.366456             1540   2025-01-10       Active
# 4  21.216345  81.360250             1772   2025-02-05       Active
#
#        manager_name         state  base_weight
# 0     Aryan Maharaj  Chhattisgarh     1.227783
# 1       Udant Dewan  Chhattisgarh     1.236357
# ...

# %%
stores.dtypes
# Out:
# store_id               str
# store_name             str
# city                   str
# area                   str
# latitude           float64
# longitude          float64
# store_size_sqft      int64
# opening_date           str
# store_status           str
# manager_name           str
# state                  str
# base_weight        float64
# dtype: object

# %%
stores.isnull().sum()
# Out:
# store_id           0
# store_name         0
# city               0
# area               0
# latitude           0
# longitude          0
# store_size_sqft    0
# opening_date       0
# store_status       0
# manager_name       0
# state              0
# base_weight        0
# dtype: int64

# %%
stores.duplicated().sum()
# Out:
# np.int64(0)

# %%
stores.describe()
# Out:
#         latitude  longitude  store_size_sqft  base_weight
# count  15.000000  15.000000        15.000000    15.000000
# mean   21.461875  81.666171      1663.866667     1.042874
# std     0.438404   0.446784       321.335354     0.203775
# min    21.102043  81.041134      1052.000000     0.677106
# 25%    21.207054  81.353726      1434.500000     0.903781
# 50%    21.230600  81.610422      1803.000000     1.055778
# 75%    21.660836  81.883610      1920.500000     1.218584
# max    22.374365  82.760963      1998.000000     1.285884

# %% [markdown]
# # Table 02:- Products

# %%
len(products)
# Out:
# 6000

# %%
products.head()
# Out:
#   product_id                  product_name                category  \
# 0    PR00001  India Gate Sunflower Oil 2kg        Staples & Grains
# 1    PR00002    Johnson's Baby Wipes 1pack               Baby Care
# 2    PR00003  Haldiram's Potato Chips 750g  Snacks & Branded Foods
# 3    PR00004          India Gate Sugar 2kg        Staples & Grains
# 4    PR00005          Fresh Potato 500pack     Fruits & Vegetables
#
#     sub_category       brand  unit      mrp  selling_price  discount_pct  \
# 0  Sunflower Oil  India Gate    kg  1177.72        1059.95            10
# 1     Baby Wipes   Johnson's  pack  1535.32        1228.26            20
# 2   Potato Chips  Haldiram's     g  1193.98        1014.88            15
# 3          Sugar  India Gate    kg   690.86         690.86             0
# 4         Potato       Fresh  pack   497.21         447.49            10
#
#    shelf_life_days
# 0               90
# 1              336
# 2              227
# 3               29
# 4               95

# %%
products.dtypes
# Out:
# product_id             str
# product_name           str
# category               str
# sub_category           str
# brand                  str
# unit                   str
# mrp                float64
# selling_price      float64
# discount_pct         int64
# shelf_life_days      int64
# dtype: object

# %%
products.isnull().sum()
# Out:
# product_id          0
# product_name        0
# category            0
# sub_category        0
# brand               0
# unit                0
# mrp                 0
# selling_price      60
# discount_pct        0
# shelf_life_days     0
# dtype: int64

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.describe()
# Out:
#                mrp  selling_price  discount_pct  shelf_life_days
# count  6000.000000    5940.000000     6000.0000      6000.000000
# mean    649.696805     592.578846        8.9900       182.201667
# std     404.587370     373.275161        8.3999       105.292819
# min      15.530000      12.750000        0.0000         1.000000
# 25%     322.980000     290.582500        0.0000        91.000000
# 50%     619.480000     564.765000       10.0000       181.500000
# 75%     933.812500     849.280000       15.0000       273.000000
# max    2144.350000    2132.180000       30.0000       364.000000

# %% [markdown]
# # Table 03:- Riders

# %%
len(riders)
# Out:
# 800

# %%
riders.head()
# Out:
#   rider_id      rider_name gender  age vehicle_type assigned_store_id  rating  \
# 0   RD0001  Chakradev Kari   Male   23         Bike             ST015     4.3
# 1   RD0002      Fariq Kaul   Male   36       E-Bike             ST009     4.2
# 2   RD0003     Lajita Mall   Male   31       E-Bike             ST009     4.6
# 3   RD0004      Janya Gaba   Male   22         Bike             ST003     4.2
# 4   RD0005    Isha Kadakia   Male   28         Bike             ST012     4.7
#
#    total_deliveries_lifetime joining_date
# 0                       1056   2025-10-13
# 1                       3857   2025-02-18
# 2                       4146   2024-10-02
# 3                       4265   2025-03-17
# 4                       3421   2026-01-20

# %%
riders.dtypes
# Out:
# rider_id                         str
# rider_name                       str
# gender                           str
# age                            int64
# vehicle_type                     str
# assigned_store_id                str
# rating                       float64
# total_deliveries_lifetime      int64
# joining_date                     str
# dtype: object

# %%
riders.isnull().sum()
# Out:
# rider_id                      0
# rider_name                    0
# gender                        0
# age                           0
# vehicle_type                  0
# assigned_store_id             0
# rating                       16
# total_deliveries_lifetime     0
# joining_date                  0
# dtype: int64

# %%
riders.duplicated().sum()
# Out:
# np.int64(0)

# %%
riders.describe()
# Out:
#              age      rating  total_deliveries_lifetime
# count  800.00000  784.000000                 800.000000
# mean    31.20000    4.404464                2977.271250
# std      7.41527    0.334814                1704.258749
# min     19.00000    3.400000                  23.000000
# 25%     25.00000    4.200000                1557.750000
# 50%     31.00000    4.400000                2986.000000
# 75%     38.00000    4.700000                4460.250000
# max     44.00000    5.000000                5996.000000

# %% [markdown]
# # Table 04:- Customers

# %%
len(customers)
# Out:
# 50100

# %%
customers.head()
# Out:
#   customer_id        customer_name  gender   age      city            area  \
# 0    CU000001      Quincy Sankaran  Female  33.0    Bhilai          Supela
# 1    CU000002           Ayush Hora    Male  49.0    Raipur  Devendra Nagar
# 2    CU000003  Pushti Ramachandran    Male  23.0    Raipur        VIP Road
# 3    CU000004           Tanish Jha  Female  25.0    Bhilai        Sector 9
# 4    CU000005          Dev Chaudry    Male  54.0  Bilaspur        Sarkanda
#
#   registered_date customer_segment preferred_payment_mode
# 0      2024-06-04        Returning                    UPI
# 1      2024-08-29              New                    UPI
# 2      2024-09-08        Returning                    UPI
# 3      2024-08-30        Returning                    UPI
# 4      2025-08-16        Returning                    UPI

# %%
customers.dtypes
# Out:
# customer_id                   str
# customer_name                 str
# gender                        str
# age                       float64
# city                          str
# area                          str
# registered_date               str
# customer_segment              str
# preferred_payment_mode        str
# dtype: object

# %%
customers.isnull().sum()
# Out:
# customer_id                  0
# customer_name                0
# gender                       0
# age                       1002
# city                         0
# area                         0
# registered_date              0
# customer_segment             0
# preferred_payment_mode       0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.describe()
# Out:
#                 age
# count  49098.000000
# mean      40.996089
# std       13.618187
# min       18.000000
# 25%       29.000000
# 50%       41.000000
# 75%       53.000000
# max       64.000000

# %% [markdown]
# # Table 05:- Orders

# %%
len(orders)
# Out:
# 1203600

# %%
orders.head()
# Out:
#      order_id customer_id store_id  order_date order_time payment_mode  \
# 0  OD00000001    CU043960    ST007  2025-04-01   11:38:34       Wallet
# 1  OD00000002    CU002190    ST002  2025-04-01   12:15:11         Card
# 2  OD00000003    CU011747    ST006  2025-04-01   12:21:48          UPI
# 3  OD00000004    CU042182    ST004  2025-04-01   08:36:45         Card
# 4  OD00000005    CU006126    ST008  2025-04-01    18:10:3         Card
#
#   order_status  discount_amount  total_amount
# 0    Delivered          1023.89       8490.70
# 1    Delivered            33.03       3727.96
# 2    Delivered           234.39      18384.10
# 3    Delivered           805.32       7227.80
# 4    Delivered           109.63       1943.64

# %%
orders.tail()
# Out:
#            order_id customer_id store_id  order_date order_time  \
# 1203595  OD00148278    CU029305    ST007  2025-05-31   22:48:20
# 1203596  OD01003200    CU012913    ST011  2026-01-29   09:59:52
# 1203597  OD00911867    CU019134    ST013  2026-01-04   21:58:19
# 1203598  OD00224567    CU049936    ST008  2025-06-26    10:28:7
# 1203599  OD00406551    CU006988    ST002  2025-08-24    22:36:0
#
#              payment_mode order_status  discount_amount  total_amount
# 1203595               UPI    Delivered           366.47       2216.15
# 1203596              Card    Delivered            15.39       1936.57
# 1203597  Cash on Delivery    Cancelled           568.30       8737.53
# 1203598               UPI    Delivered           200.48       1396.03
# 1203599            Wallet    Delivered           856.14       6589.02

# %%
orders.dtypes
# Out:
# order_id               str
# customer_id            str
# store_id               str
# order_date             str
# order_time             str
# payment_mode           str
# order_status           str
# discount_amount    float64
# total_amount       float64
# dtype: object

# %%
orders.isnull().sum()
# Out:
# order_id               0
# customer_id            0
# store_id               0
# order_date             0
# order_time             0
# payment_mode           0
# order_status           0
# discount_amount    12036
# total_amount       12036
# dtype: int64

# %%
# NOTE: full-row duplicated() is not the right check on its own for this table --
# see the order_id.nunique() check right below it. Keeping both here on purpose.
orders.duplicated().sum()
# Out:
# np.int64(3168)

# %%
orders['order_id'].nunique()
# Out:
# 1200000

# %%
orders.describe()
# Out:
#        discount_amount  total_amount
# count     1.191564e+06  1.191564e+06
# mean      3.305622e+02  4.092628e+03
# std       3.212864e+02  2.742654e+03
# min      -2.506320e+03  1.088000e+01
# 25%       9.575000e+01  2.031727e+03
# 50%       2.356650e+02  3.564090e+03
# 75%       4.684800e+02  5.575612e+03
# max       3.891130e+03  2.771273e+04

# %% [markdown]
# # Table 06:- Order_Items

# %%
len(order_items)
# Out:
# 4500000

# %%
order_items.head()
# Out:
#   order_item_id    order_id product_id  quantity  unit_price  line_total
# 0   OI000000001  OD00000001    PR04938         3      919.22     2757.66
# 1   OI000000002  OD00000001    PR00635         1      585.97      585.97
# 2   OI000000003  OD00000001    PR00963         1      175.16      175.16
# 3   OI000000004  OD00000001    PR01628         1       82.44       82.44
# 4   OI000000005  OD00000001    PR02886         3      989.86     2969.58

# %%
order_items.tail()
# Out:
#         order_item_id    order_id product_id  quantity  unit_price  line_total
# 4499995   OI004499996  OD01200000    PR03775         1     1155.75     1155.75
# 4499996   OI004499997  OD01200000    PR03628         2      174.76      349.52
# 4499997   OI004499998  OD01200000    PR03367         3      323.24      969.72
# 4499998   OI004499999  OD01200000    PR05544         4      438.35     1753.40
# 4499999   OI004500000  OD01200000    PR04338         4      277.40     1109.60

# %%
order_items.dtypes
# Out:
# order_item_id        str
# order_id             str
# product_id           str
# quantity           int64
# unit_price       float64
# line_total       float64
# dtype: object

# %%
order_items.isnull().sum()
# Out:
# order_item_id        0
# order_id             0
# product_id           0
# quantity             0
# unit_price       22500
# line_total           0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items.describe()
# Out:
#            quantity    unit_price    line_total
# count  4.500000e+06  4.477500e+06  4.500000e+06
# mean   2.033983e+00  5.755142e+02  1.179953e+03
# std    1.230532e+00  3.825580e+02  1.142580e+03
# min   -5.000000e+00  1.153000e+01  1.160000e+01
# 25%    1.000000e+00  2.870000e+02  3.965300e+02
# 50%    2.000000e+00  5.264400e+02  8.327400e+02
# 75%    3.000000e+00  8.369300e+02  1.593200e+03
# max    5.000000e+00  2.397490e+03  1.133380e+04

# %% [markdown]
# # Table 07:- Deliveries

# %%
len(deliveries)
# Out:
# 1200000

# %%
deliveries.head()
# Out:
#    delivery_id    order_id rider_id store_id  promised_time_minutes  \
# 0  DL000000001  OD00000001   RD0576    ST007                      8
# 1  DL000000002  OD00000002   RD0499    ST002                     15
# 2  DL000000003  OD00000003   RD0256    ST006                     12
# 3  DL000000004  OD00000004   RD0315    ST004                     12
# 4  DL000000005  OD00000005   RD0467    ST008                     10
#
#    actual_delivery_time_minutes  distance_km delivery_status
# 0                          24.7         2.15         Delayed
# 1                          21.5         1.59         Delayed
# 2                          15.6         0.61         On-time
# 3                          14.0         3.30         On-time
# 4                          14.7         0.94         On-time

# %%
deliveries.tail()
# Out:
#          delivery_id    order_id rider_id store_id  promised_time_minutes  \
# 1199995  DL001199996  OD01199996   RD0728    ST011                     10
# 1199996  DL001199997  OD01199997   RD0656    ST006                     10
# 1199997  DL001199998  OD01199998   RD0368    ST006                     10
# 1199998  DL001199999  OD01199999   RD0785    ST011                     12
# 1199999  DL001200000  OD01200000   RD0257    ST010                     10
#
#          actual_delivery_time_minutes  distance_km delivery_status
# 1199995                          14.9         0.93         On-time
# 1199996                          11.6         1.25         On-time
# 1199997                          15.2         1.12         Delayed
# 1199998                          14.7         1.00         On-time
# 1199999                          13.0         1.03         On-time

# %%
deliveries.dtypes
# Out:
# delivery_id                         str
# order_id                            str
# rider_id                            str
# store_id                            str
# promised_time_minutes             int64
# actual_delivery_time_minutes    float64
# distance_km                     float64
# delivery_status                     str
# dtype: object

# %%
deliveries.isnull().sum()
# Out:
# delivery_id                         0
# order_id                            0
# rider_id                         6000
# store_id                            0
# promised_time_minutes               0
# actual_delivery_time_minutes    83977
# distance_km                     12000
# delivery_status                     0
# dtype: int64

# %%
deliveries.duplicated().sum()
# Out:
# np.int64(0)

# %%
deliveries.describe()
# Out:
#        promised_time_minutes  actual_delivery_time_minutes   distance_km
# count           1.200000e+06                  1.116023e+06  1.188000e+06
# mean            1.094705e+01                  1.782486e+01  1.543207e+00
# std             2.107190e+00                  1.648627e+01  1.021807e+00
# min             8.000000e+00                  8.000000e+00  3.000000e-01
# 25%             1.000000e+01                  1.350000e+01  7.800000e-01
# 50%             1.000000e+01                  1.620000e+01  1.310000e+00
# 75%             1.200000e+01                  1.950000e+01  2.060000e+00
# max             1.500000e+01                  3.999884e+02  6.000000e+00

# %%
deliveries['delivery_status'].value_counts()
# Out:
# delivery_status
# On-time      559141
# Delayed      556627
# Cancelled     84232
# Name: count, dtype: int64

# %% [markdown]
# # Table 08:- Inventory

# %%
len(inventory)
# Out:
# 471135

# %%
inventory.head()
# Out:
#   inventory_id store_id product_id snapshot_date  stock_quantity  \
# 0   IN00000001    ST001    PR03835    2025-04-07           449.0
# 1   IN00000002    ST001    PR01696    2025-04-07           302.0
# 2   IN00000003    ST001    PR04349    2025-04-07           118.0
# 3   IN00000004    ST001    PR00021    2025-04-07            33.0
# 4   IN00000005    ST001    PR01466    2025-04-07           215.0
#
#    reorder_level restock_flag
# 0             81           No
# 1             57           No
# 2             49           No
# 3             87          Yes
# 4             33           No

# %%
inventory.tail()
# Out:
#        inventory_id store_id product_id snapshot_date  stock_quantity  \
# 471130   IN00471131    ST015    PR05696    2026-03-30           398.0
# 471131   IN00471132    ST015    PR01599    2026-03-30           218.0
# 471132   IN00471133    ST015    PR00426    2026-03-30            92.0
# 471133   IN00471134    ST015    PR05046    2026-03-30           335.0
# 471134   IN00471135    ST015    PR01670    2026-03-30           144.0
#
#         reorder_level restock_flag
# 471130             55           No
# 471131             47           No
# 471132             64           No
# 471133             72           No
# 471134             68           No

# %%
inventory.dtypes
# Out:
# inventory_id          str
# store_id              str
# product_id            str
# snapshot_date         str
# stock_quantity    float64
# reorder_level       int64
# restock_flag          str
# dtype: object

# %%
inventory.isnull().sum()
# Out:
# inventory_id         0
# store_id             0
# product_id           0
# snapshot_date        0
# stock_quantity    4703
# reorder_level        0
# restock_flag         0
# dtype: int64

# %%
inventory.duplicated().sum()
# Out:
# np.int64(0)

# %%
inventory.describe()
# Out:
#        stock_quantity  reorder_level
# count   466432.000000  471135.000000
# mean       248.914080      59.519632
# std        144.740047      23.103368
# min        -49.000000      20.000000
# 25%        124.000000      40.000000
# 50%        249.000000      60.000000
# 75%        374.000000      80.000000
# max        499.000000      99.000000
